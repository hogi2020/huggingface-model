# %%
# 허깅페이스의 Transformer 라이브러리 설치
# !pip install transformers
# !pip install torch
# !pip install huggingface_hub[hf_xet]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# GPT-2 모델과 토크나이저 로드하기
model_name = "skt/kogpt2-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 텍스트 생성 파이프라인 초기화
generator = pipeline('text-generation', model=model, tokenizer=tokenizer)

# 블로그 글 생성
blog_post = generator(
    "인공지능이 현대 사회에 미치는 영향",
    max_length=500,
    num_return_sequences=1,
    no_repeat_ngram_size=2,
    temperature=0.7,
    top_k=50,
    top_p=0.95
)

# 결과 출력
print(blog_post[0]['generated_text'])
# Out:
# c:\Users\junmy\miniconda3\envs\deepenv\Lib\site-packages\huggingface_hub\file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\junmy\miniconda3\envs\deepenv\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\junmy\.cache\huggingface\hub\models--skt--kogpt2-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# 인공지능이 현대 사회에 미치는 영향과 시사점을 소개한다.
# 이번 강연은 한국정보화진흥원 전문위원과 한국과학기술정보연구원(KISTI) 박재문 원장이 나서 '인터넷이 가져온 새로운 변화'를 주제로 진행한다.
# 특히 박 원장은 인터넷이 가져올 변화를 소개하며 미래 인터넷의 핵심기술로 '스마트홈'과 '웨어러블' 등을 꼽았다.
# 또 최근 국내 모바일 시장에서 가장 주목 받고 있는 인공신경망 기술인 인공비디오(AI)를 주제로 강연한다.
# 이와 함께 이달 초 오픈한 '빅데이터'를 활용한 모바일 앱을 소개할 예정이다.
# 이밖에 '데이터를 활용한 새로운 가치 창출'을 주제로 김지현 삼성SDS 연구원과 황원섭 KT 미래기술연구소 책임연구원이 강연에 나선다.
# 아울러 이강래 한국전자통신연구원 선임연구원은 '디지털 트랜스포메이션'을, 박선영 SK텔레콤 사장은 '모바일 커넥티드 카'를, 유준상 한국무역협회 국제무역연구원 연구위원은 'AI를 통한 산업 생태계 발전'을 각각 주제로 강연을 진행할 예정이다.
# KT 관계자는 "다양한 분야의 전문가를 초청해 4차 산업혁명 시대를 이끌어갈 인재 양성 프로그램을 기획하고 있다"며 "K-ICT인재양성 프로그램 외에도 다양한 분야에서 다양한 활동을 펼칠 계획"이라고 말했다. 코로나19가 장기화하면서 국내 IT 분야에서도 기업들의 어려움이 가중되고 있다.
# 삼성전자는 국내 PC시장에서 점유율 1위를 지키며 1위를 유지하고 있지만 해외시장에서 판매 부진으로 어려움을 겪고 있다.
# 이런 가운데 구글과 아마존이 국내에 진출하면서 스마트폰 시장에도 새로운 지각변동이 예상된다.
# 4일 관련업계에 따르면 구글을 비롯해 아마존, 애플, 마이크로소프트(MS), 페이스북 등 주요 IT 기업들은 스마트폰 시장에 본격적으로 뛰어들 채비를 하고 있다.
# 구글은 지난달 모바일 운영체제 안드로이드OS(운영체제)를 탑재한 신제품 `넥서스원(Nexus One)'을 국내에 출시했다.
# 특히 구플은 올해 국내 스마트폰 판매 목표를 1억대 이상으로 잡고 있다.
# 애플은 최근 신형 아이폰을 발표하며 올 상반기 국내시장 점유율을 30%로 확대할 계획이다.
# 애플의 경우 지난해 한국 시장에서 점유율이 29%로 1위를 차지한 바 있다.
# 앞서 애플로선 올 1분기 점유율은 11%로 구작 `아이폰6S`보다 높은 것으로 알려졌다.
# 구글을 비롯한 미국 스마트폰 제조업체들도 국내 시장 공략을 서두르고 있다.
# 업계 관계자들은 "세계 스마트폰 시장이 스마트폰에서 PC로 빠르게 이동하고 있는 상황에서
